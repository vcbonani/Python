# %% [markdown]
# <a href="https://colab.research.google.com/github/vcbonani/Python/blob/main/Pandas_IO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#Lendo arquivos CSV
url_csv = 'https://raw.githubusercontent.com/alura-cursos/Pandas/refs/heads/main/superstore_data.csv'
dados_mercado = pd.read_csv(url_csv, sep = ',') #gera um dataframe do arquivo csv
dados_mercado.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
url_csv_ponto_virgula = 'https://raw.githubusercontent.com/alura-cursos/Pandas/refs/heads/main/superstore_data_ponto_virgula.csv'
dados_mercado_2 = pd.read_csv(url_csv_ponto_virgula, sep = ';')
dados_mercado_2.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
#como detectar qual a codificação (enconding) de um arquivo
import chardet

with open('superstore_data.csv', 'rb') as file:
    print(chardet.detect(file.read()))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2696979448.py in <cell line: 0>()
#       2 import chardet
#       3
# ----> 4 with open('superstore_data.csv', 'rb') as file:
#       5     print(chardet.detect(file.read()))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'superstore_data.csv'

# %%
#nrows -> determina quantas linhas eu quero do arquivo
dados_primeiras_linhas = pd.read_csv(url_csv, nrows = 10)
dados_primeiras_linhas
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
# 5   7348        1958         PhD         Single   71691        0         0
# 6   4073        1954    2n Cycle        Married   63564        0         0
# 7   1991        1967  Graduation       Together   44931        0         1
# 8   4047        1954         PhD        Married   65324        0         1
# 9   9477        1954         PhD        Married   65324        0         1
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# ...

# %%
#usecols -> selecione somente as colunas que o usuário informar com o nome da coluna ou o número da posição da coluna
dados_selecao = pd.read_csv(url_csv, usecols = ['Id', 'Year_Birth', 'Income'])
dados_selecao = pd.read_csv(url_csv, usecols = [0, 1, 4])
dados_selecao
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
#exporta o dataframe para um csv
#o parâmetro index não cria um novo índice
dados_selecao.to_csv('dados_mercado_selecao.csv', index = False)

# %%
#lendo o csv exportado
dados_exportados = pd.read_csv('/content/dados_mercado_selecao.csv')
dados_exportados
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
#Desafio: lendo dados com vários parâmetros

#verificando a codificação do arquivo: ISO-8859-1
with open('dados_sus.csv', 'rb') as file:
    print(chardet.detect(file.read()))

url_dados_sus = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/dados_sus.csv'

#separados é ponto e vírgula, encoding é ISO-8859-1, o header é a partir da 4ª linha, o skipfooter desconsidera as últimas 9 linhas
dados_sus = pd.read_csv(url_dados_sus, sep = ';', encoding = 'ISO-8859-1', header = 3, skipfooter = 9, engine = 'python')

dados_sus
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3145820923.py in <cell line: 0>()
#       2
#       3 #verificando a codificação do arquivo: ISO-8859-1
# ----> 4 with open('dados_sus.csv', 'rb') as file:
#       5     print(chardet.detect(file.read()))
#       6
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dados_sus.csv'

# %%
## trabalhando com arquivo excel

url = 'https://github.com/alura-cursos/Pandas/blob/main/emissoes_CO2.xlsx?raw=True'

#obtém o nome das páginas(sheets) do excel
pd.ExcelFile(url).sheet_names
# Out:
# ['emissoes_C02', 'emissoes_percapita', 'fontes']

# %%
dados_co2 = pd.read_excel(url)

# %%
dados_co2
# Out:
#               País ISO 3166-1 alpha-3   Ano         Total        Carvão  \
# 0      Afeganistão                AFG  1750  0.000000e+00           NaN
# 1      Afeganistão                AFG  1751  0.000000e+00           NaN
# 2      Afeganistão                AFG  1752  0.000000e+00           NaN
# 3      Afeganistão                AFG  1753  0.000000e+00           NaN
# 4      Afeganistão                AFG  1754  0.000000e+00           NaN
# ...            ...                ...   ...           ...           ...
# 63099       Global                WLD  2017  3.609674e+10  1.450697e+10
# 63100       Global                WLD  2018  3.682651e+10  1.474683e+10
# 63101       Global                WLD  2019  3.708256e+10  1.472598e+10
# 63102       Global                WLD  2020  3.526409e+10  1.417456e+10
# 63103       Global                WLD  2021  3.712385e+10  1.497960e+10
#
#                Oléo           Gás       Cimento       Queima        Outro  \
# ...

# %%
percapita = pd.read_excel(url, sheet_name = 'emissoes_percapita')

# %%
percapita
# Out:
#               País ISO 3166-1 alpha-3   Ano      Total     Carvão       Óleo  \
# 0      Afeganistão                AFG  1750        NaN        NaN        NaN
# 1      Afeganistão                AFG  1751        NaN        NaN        NaN
# 2      Afeganistão                AFG  1752        NaN        NaN        NaN
# 3      Afeganistão                AFG  1753        NaN        NaN        NaN
# 4      Afeganistão                AFG  1754        NaN        NaN        NaN
# ...            ...                ...   ...        ...        ...        ...
# 63099       Global                WLD  2017  4749682.0  1908857.0  1610910.0
# 63100       Global                WLD  2018  4792753.0  1919213.0  1596350.0
# 63101       Global                WLD  2019  4775633.0  1896468.0  1589920.0
# 63102       Global                WLD  2020  4497423.0  1807760.0  1427353.0
# 63103       Global                WLD  2021  4693699.0  1893923.0  1496614.0
#
#              Gás   Cimento   Queima    Outro
# ...

# %%
fontes = pd.read_excel(url, sheet_name = 'fontes')

# %%
fontes
# Out:
#               País ISO 3166-1 alpha-3   Ano  \
# 0      Afeganistão                AFG  1750
# 1      Afeganistão                AFG  1751
# 2      Afeganistão                AFG  1752
# 3      Afeganistão                AFG  1753
# 4      Afeganistão                AFG  1754
# ...            ...                ...   ...
# 63099       Global                WLD  2017
# 63100       Global                WLD  2018
# 63101       Global                WLD  2019
# 63102       Global                WLD  2020
# 63103       Global                WLD  2021
#
#                                       Total             Carvão  \
# 0                                    [NONE]             [NONE]
# 1                                    [NONE]             [NONE]
# 2                                    [NONE]             [NONE]
# 3                                    [NONE]             [NONE]
# 4                                    [NONE]             [NONE]
# ...

# %%
#o parâmetro usecols permite selecionar algumas colunas do arquivo de origem
#no exemplo, são selecionadas as colunas de A a D
intervalo = pd.read_excel(url, sheet_name = 'emissoes_C02', usecols = 'A:D')

# %%
intervalo
# Out:
#               País ISO 3166-1 alpha-3   Ano         Total
# 0      Afeganistão                AFG  1750  0.000000e+00
# 1      Afeganistão                AFG  1751  0.000000e+00
# 2      Afeganistão                AFG  1752  0.000000e+00
# 3      Afeganistão                AFG  1753  0.000000e+00
# 4      Afeganistão                AFG  1754  0.000000e+00
# ...            ...                ...   ...           ...
# 63099       Global                WLD  2017  3.609674e+10
# 63100       Global                WLD  2018  3.682651e+10
# 63101       Global                WLD  2019  3.708256e+10
# 63102       Global                WLD  2020  3.526409e+10
# 63103       Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %%
#o parâmetro nrows obtém somente a quantidade de linhas especificadas, no exemplo são só 10
intervalo_2 = pd.read_excel(url, sheet_name='emissoes_C02', usecols = 'A:D', nrows=10)

# %%
intervalo_2
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total
# 0  Afeganistão                AFG  1750      0
# 1  Afeganistão                AFG  1751      0
# 2  Afeganistão                AFG  1752      0
# 3  Afeganistão                AFG  1753      0
# 4  Afeganistão                AFG  1754      0
# 5  Afeganistão                AFG  1755      0
# 6  Afeganistão                AFG  1756      0
# 7  Afeganistão                AFG  1757      0
# 8  Afeganistão                AFG  1758      0
# 9  Afeganistão                AFG  1759      0

# %%
#exportando um dataframe para excel
percapita.to_excel('co2_percapita.xlsx', index = False)

# %%
#essa é a url de uma planilha no drive                       entre o d/ e o /edit está o id da planilha que será usado
#                                                            |||||||||||||||||||||||||||||||||
url_planilha_drive = 'https://docs.google.com/spreadsheets/d/1e-dOLdElnztbUa7kUDre5k2PJfx4bLsu/edit?usp=sharing&ouid=110788630261722409853&rtpof=true&sd=true'

sheet_id = '1e-dOLdElnztbUa7kUDre5k2PJfx4bLsu'

#os parâmetros /gviz/tq usa uma api do google drive para acessar a planilha
#o parâmetro tqx=out:csv informa que ele será exportado como um arquivo csv
#o parâmetro sheet sem nada exportará a primeira aba do arquivo
url_drive = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

dados_co2_sheets = pd.read_csv(url_drive)

# %%
dados_co2_sheets
# Out:
#               País ISO 3166-1 alpha-3   Ano           Total          Carvão  \
# 0      Afeganistão                AFG  1750               0             NaN
# 1      Afeganistão                AFG  1751               0             NaN
# 2      Afeganistão                AFG  1752               0             NaN
# 3      Afeganistão                AFG  1753               0             NaN
# 4      Afeganistão                AFG  1754               0             NaN
# ...            ...                ...   ...             ...             ...
# 63099       Global                WLD  2017  36.096.739.276  14.506.973.805
# 63100       Global                WLD  2018  36.826.506.600  14.746.830.688
# 63101       Global                WLD  2019  37.082.558.969  14.725.978.025
# 63102       Global                WLD  2020  35.264.085.734  14.174.564.010
# 63103       Global                WLD  2021  37.123.850.352  14.979.598.083
#
# ...

# %%
sheet_id = '1e-dOLdElnztbUa7kUDre5k2PJfx4bLsu'
sheet_name = 'emissoes_percapita'
#aqui, o parâmetro sheet traz a informação explícita de qual aba será exportada
url_percapita = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

percapita_sheets = pd.read_csv(url_percapita)

# %%
percapita_sheets
# Out:
#               País ISO 3166-1 alpha-3   Ano      Total     Carvão       Óleo  \
# 0      Afeganistão                AFG  1750        NaN        NaN        NaN
# 1      Afeganistão                AFG  1751        NaN        NaN        NaN
# 2      Afeganistão                AFG  1752        NaN        NaN        NaN
# 3      Afeganistão                AFG  1753        NaN        NaN        NaN
# 4      Afeganistão                AFG  1754        NaN        NaN        NaN
# ...            ...                ...   ...        ...        ...        ...
# 63099       Global                WLD  2017  4.749.682  1.908.857  1.610.910
# 63100       Global                WLD  2018  4.792.753  1.919.213  1.596.350
# 63101       Global                WLD  2019  4.775.633  1.896.468  1.589.920
# 63102       Global                WLD  2020  4.497.423  1.807.760  1.427.353
# 63103       Global                WLD  2021  4.693.699  1.893.923  1.496.614
#
#              Gás  Cimento  Queima   Outro
# ...

# %%
sheet_id = '1e-dOLdElnztbUa7kUDre5k2PJfx4bLsu'
sheet_name = 'fontes'
url_fontes = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

fontes_sheets = pd.read_csv(url_fontes)

# %%
fontes_sheets
# Out:
#               País ISO 3166-1 alpha-3   Ano  \
# 0      Afeganistão                AFG  1750
# 1      Afeganistão                AFG  1751
# 2      Afeganistão                AFG  1752
# 3      Afeganistão                AFG  1753
# 4      Afeganistão                AFG  1754
# ...            ...                ...   ...
# 63099       Global                WLD  2017
# 63100       Global                WLD  2018
# 63101       Global                WLD  2019
# 63102       Global                WLD  2020
# 63103       Global                WLD  2021
#
#                                       Total             Carvão  \
# 0                                    [NONE]             [NONE]
# 1                                    [NONE]             [NONE]
# 2                                    [NONE]             [NONE]
# 3                                    [NONE]             [NONE]
# 4                                    [NONE]             [NONE]
# ...

# %%
#Desafio: lendo dados de outro link

url_desafio_original = 'https://docs.google.com/spreadsheets/d/1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw/edit?gid=1214654498#gid=1214654498'

##pegar o id do arquivo do drive usando regex
import re

padrao = r"/d/([a-zA-Z0-9-_]+)/edit"
id_arquivo = re.search(padrao, url_desafio_original)
print(id_arquivo)

if id_arquivo:
  id_arquivo = id_arquivo.group(1)
  print(id_arquivo)
1
url_desafio = f'https://docs.google.com/spreadsheets/d/{id_arquivo}/gviz/tq?tqx=out:csv&sheet'

dados_desafio = pd.read_csv(url_desafio)
dados_desafio.head()

dados_desafio.to_csv('emissoes_co2.csv', index = False)
# Out:
# <re.Match object; span=(36, 88), match='/d/1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw/e>
# 1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw

# %%
## MANIPULANDO ARQUIVOS JSON Javascript Object Notation

import pandas as pd

dados_pacientes = pd.read_json('/content/pacientes.json')

# %%
dados_pacientes
# Out:
#      ID_paciente Doenca_cardiaca    IMC Fumante Consumo_alcool  AVC  \
# 0              0             Nao  16.60     Sim            Nao  Nao
# 1              1             Nao  20.34     Nao            Nao  Sim
# 2              2             Nao  26.58     Sim            Nao  Nao
# 3              3             Nao  24.21     Nao            Nao  Nao
# 4              4             Nao  23.71     Nao            Nao  Nao
# ..           ...             ...    ...     ...            ...  ...
# 995          995             Nao  28.29     Sim            Nao  Nao
# 996          996             Nao  25.69     Sim            Nao  Nao
# 997          997             Sim  26.99     Nao            Nao  Nao
# 998          998             Nao  44.29     Nao            Nao  Nao
# 999          999             Nao  25.83     Nao            Nao  Nao
#
#      Saude_fisica  Saude_mental Dificuldade_caminhar Sexo_biologico  \
# 0               3            30                  Nao       Feminino
# ...

# %%
#este arquivo json não está normalizado, está aninhado
dados_pacients_2 = pd.read_json('/content/pacientes_2.json')
dados_pacients_2
# Out:
#                                     Pesquisa   Ano  \
# 0  Principais Indicadores de Doenca Cardiaca  2020
# 1  Principais Indicadores de Doenca Cardiaca  2020
# 2  Principais Indicadores de Doenca Cardiaca  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Faixa_etaria': '55-59', 'Sexo_bi...
# 1  {'ID': '02', 'Faixa_etaria': '80 ou +', 'Sexo_...
# 2  {'ID': '03', 'Faixa_etaria': '65-69', 'Sexo_bi...

# %%
#json_normalize normaliza os dados para um dataframe a partir da coluna especificada
df_normalizado = pd.json_normalize(dados_pacients_2['Pacientes'])
df_normalizado
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0  01        55-59       Feminino  Branca  16.60     Sim            Nao
# 1  02      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2  03        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]

# %%
#usando módulo JSON para importar arquivos json

import json

with open('/content/pacientes_2.json') as f:
  dados = json.loads(f.read())

pd.json_normalize(dados, record_path='Pacientes')
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0  01        55-59       Feminino  Branca  16.60     Sim            Nao
# 1  02      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2  03        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]

# %%
#salvando um arquivo JSON

df_normalizado.to_json('df_normalizado.json')

# %%
## IMPORTANDO UM JSON A PARTIR DE UMA API

import requests #a biblioteca requests contém as formas de obter o json de uma api
import json

#obtém o json
dados_usuarios = requests.get('https://jsonplaceholder.typicode.com/users')

#json.loads lê o json obtido
resultado = json.loads(dados_usuarios.text)

#visualizando como um dataframe o json
pd.DataFrame(resultado)

#normalizando o json
df_normalizado = pd.json_normalize(resultado)
df_normalizado
# Out:
#    id                      name          username                      email  \
# 0   1             Leanne Graham              Bret          Sincere@april.biz
# 1   2              Ervin Howell         Antonette          Shanna@melissa.tv
# 2   3          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3   4          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4   5          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5   6      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6   7           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7   8  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8   9           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9  10        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#                    phone        website     address.street address.suite  \
# ...

# %%
##Lendo páginas web
import pandas as pd

# %%
dados_html = pd.read_html('/content/filmes_wikipedia.html')
#o read_html busca as tags tables dentro da página web

dados_html
# Out:
# [       0                      1
#  0   1998             100 Movies
#  1   1999              100 Stars
#  2   2000             100 Laughs
#  3   2001            100 Thrills
#  4   2002           100 Passions
#  5   2003  100 Heroes & Villains
#  6   2004              100 Songs
#  7   2005       100 Movie Quotes
#  8   2005              25 Scores
#  9   2006             100 Cheers
#  10  2006            25 Musicals
#  11  2007   100 Movies (Updated)
#  12  2008        AFI's 10 Top 10
#  13   vte                    vte,
#                              Film  Release year              Director  \
#  0                   Citizen Kane          1941          Orson Welles
#  1                     Casablanca          1942        Michael Curtiz
#  2                  The Godfather          1972  Francis Ford Coppola
#  3             Gone with the Wind          1939        Victor Fleming
#  4             Lawrence of Arabia          1962            David Lean
# ...

# %%
type(dados_html) #confirmando que é uma lista
len(dados_html) #confirmando que contém 3 tabelas
# Out:
# 3

# %%
top_filmes = dados_html[1] #passa a tabela desejada para uma variável

top_filmes
# Out:
#                             Film  Release year              Director  \
# 0                   Citizen Kane          1941          Orson Welles
# 1                     Casablanca          1942        Michael Curtiz
# 2                  The Godfather          1972  Francis Ford Coppola
# 3             Gone with the Wind          1939        Victor Fleming
# 4             Lawrence of Arabia          1962            David Lean
# ..                           ...           ...                   ...
# 95                 The Searchers          1956             John Ford
# 96              Bringing Up Baby          1938          Howard Hawks
# 97                    Unforgiven          1992        Clint Eastwood
# 98  Guess Who's Coming to Dinner          1967        Stanley Kramer
# 99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                       Production companies  Rank
# 0                       RKO Radio Pictures     1
# ...

# %%
#escrevendo um arquivo html a partir de uma variável
top_filmes.to_html('top_filmes.html')

# %%
#salvando em csv
top_filmes.to_csv('top_filmes.csv', index = False)

# %%
#Lendo e escrevendo arquivos XML

dados_imdb = pd.read_xml('/content/imdb_top_1000.xml')
dados_imdb
# Out:
#      index                                        Poster_Link  \
# 0        0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1        1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2        2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3        3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4        4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..     ...                                                ...
# 995    995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996    996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997    997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998    998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999    999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# ...

# %%
#selecionando somente algumas colunas do dataframe
dados_imdb = dados_imdb.iloc[:, 2:10]
dados_imdb
# Out:
#     Certificate  Runtime                     Genre  IMDB_Rating  \
# 0             A  142 min                     Drama          9.3
# 1             A  175 min              Crime, Drama          9.2
# 2            UA  152 min      Action, Crime, Drama          9.0
# 3             A  202 min              Crime, Drama          9.0
# 4             U   96 min              Crime, Drama          9.0
# ..          ...      ...                       ...          ...
# 995           A  115 min    Comedy, Drama, Romance          7.6
# 996           G  201 min            Drama, Western          7.6
# 997      Passed  118 min       Drama, Romance, War          7.6
# 998        None   97 min                Drama, War          7.6
# 999        None   86 min  Crime, Mystery, Thriller          7.6
#
#                                               Overview  Meta_score
# 0    Two imprisoned men bond over a number of years...        80.0
# ...

# %%
#exportando o dataframe para um xml
dados_imdb.to_xml('filmes_imdb.xml', index = False)

# %%
#Desafio: lendo uma tabela de uma página web

dados_populacao = pd.read_html('/content/Lista de países por população.html')

#conferindo os dados importados
dados_populacao
# Out:
# [     Unnamed: 0 Posição                    País (ou território dependente)  \
#  0           NaN       1                                              Índia
#  1           NaN       2                                      China[nota 1]
#  2           NaN       3                                     Estados Unidos
#  3           NaN       4                                          Indonésia
#  4           NaN       5                                          Paquistão
#  ..          ...     ...                                                ...
#  245         NaN       –                     Ilha de Ascensão (Reino Unido)
#  246         NaN     195                                           Vaticano
#  247         NaN       –  [[File:|22x20px|border |alt=|link=]] Ilhas Coc...
#  248         NaN       –                     Tristão da Cunha (Reino Unido)
#  249         NaN       –                       Ilhas Pitcairn (Reino Unido)
#
# ...

# %%
#conferindo quantas tabelas existem
len(dados_populacao)

#selecionando a primeira tabela
dados_populacao = dados_populacao[0]

# %%
#desconsiderando a coluna unnamed, crescimento desde a última estimativa, estimativa oficial
dados_populacao = dados_populacao.iloc[:, 1:4]

# %%
#analisando os dados
pd.set_option('display.max_rows', None)
dados_populacao
# Out:
#     Posição                    País (ou território dependente)  \
# 0         1                                              Índia
# 1         2                                      China[nota 1]
# 2         3                                     Estados Unidos
# 3         4                                          Indonésia
# 4         5                                          Paquistão
# 5         6                                            Nigéria
# 6         7                                             Brasil
# 7         8                                         Bangladesh
# 8         9                                     Rússia[nota 2]
# 9        10                                             México
# 10       11                                            Etiópia
# 11       12                                              Japão
# 12       13                                          Filipinas
# 13       14                     República Democrática do Congo
# ...

# %%
pd.reset_option('display.max_rows')

#tratando os dados

#Substituindo os textos de [Nota 1], [Nota 2] e [[File:|22x20px|border |alt=|link=]] na coluna de País
dados_populacao.replace(r'\[+.*?\]+', '', regex=True, inplace=True)

#confirmando a aplicação da substituição
dados_populacao.head(10)
# Out:
#   Posição País (ou território dependente) Estimativa da ONU
# 0       1                           Índia     1 417 492 000
# 1       2                           China     1 407 934 000
# 2       3                  Estados Unidos       342 181 000
# 3       4                       Indonésia       285 783 000
# 4       5                       Paquistão       256 204 000
# 5       6                         Nigéria       236 213 000
# 6       7                          Brasil       214 244 000
# 7       8                      Bangladesh       177 567 000
# 8       9                          Rússia       146 022 000
# 9      10                          México       131 013 000

# %%
#conferindo o restante dos dados
dados_populacao.tail(10)
# Out:
#     Posição     País (ou território dependente) Estimativa da ONU
# 240       –            Ilha Norfolk (Austrália)             2 169
# 241       –          Ilha Christmas (Austrália)             1 996
# 242       –                Saba (Países Baixos)             1 933
# 243       –                Niue (Nova Zelândia)             1 626
# 244       –             Tokelau (Nova Zelândia)             1 411
# 245       –      Ilha de Ascensão (Reino Unido)             1 100
# 246     195                            Vaticano               879
# 247       –   Ilhas Cocos (Keeling) (Austrália)               605
# 248       –      Tristão da Cunha (Reino Unido)               264
# 249       –        Ilhas Pitcairn (Reino Unido)                67

# %%
#transformando a coluna Estimativa da ONU para número
dados_populacao['Estimativa da ONU'] = dados_populacao['Estimativa da ONU'].str.replace(' ','', regex = False).astype(int)

# %%
#conferindo o tipo da coluna
dados_populacao.dtypes
# Out:
# Posição                            object
# País (ou território dependente)    object
# Estimativa da ONU                   int64
# dtype: object

# %%
##Trabalhando com banco de dados

import sqlalchemy

# %%
'''fazendo importações do sqlalchemy
create_engine - motor para conexão com banco de dados
MetaData - classe que representa os metadados do BD
Table - representa uma tabela em um BD
inspect - permite inspecionar a estrutura do BD
'''
from sqlalchemy import create_engine, MetaData, Table, inspect

# %%
#criando um banco de dados do tipo sqlite, armazenar o banco na memória local
engine = create_engine('sqlite:///:memory:')

# %%
#base de dados csv

url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/clientes_banco.csv'

# %%
import pandas as pd

# %%
dados = pd.read_csv(url)

# %%
dados.head()
# Out:
#    ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0     5008804     32   Ensino superior  União-estável                2
# 1     5008805     32   Ensino superior  União-estável                2
# 2     5008806     58      Ensino médio         Casado                2
# 3     5008808     52      Ensino médio       Solteiro                1
# 4     5008809     52      Ensino médio       Solteiro                1
#
#     Categoria_de_renda   Ocupacao  Anos_empregado  Rendimento_anual  \
# 0            Empregado      Outro              12          427500.0
# 1            Empregado      Outro              12          427500.0
# 2            Empregado  Segurança               3          112500.0
# 3  Associado comercial     Vendas               8          270000.0
# 4  Associado comercial     Vendas               8          270000.0
#
#    Tem_carro                   Moradia
# 0          1       Apartamento alugado
# 1          1       Apartamento alugado
# ...

# %%
#transformar um dataframe para banco de dados

#é passado o dataframe, qual o motor(engine) e a não-criação automática de índice
dados.to_sql('clientes', engine, index = False)
# Out:
# 438463

# %%
#inspecionando o que existe no banco de dados
inspetor = inspect(engine)

#confirmando as tabelas criadas
print(inspetor.get_table_names())
# Out:
# ['clientes']

# %%
#criando uma consulta no banco de dados
query = 'select * from clientes where Categoria_de_renda = "Empregado"'

# %%
#lendo o banco de dados
empregados = pd.read_sql(query, engine)

empregados.head()
# Out:
#    ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0     5008804     32   Ensino superior  União-estável                2
# 1     5008805     32   Ensino superior  União-estável                2
# 2     5008806     58      Ensino médio         Casado                2
# 3     5008815     46   Ensino superior         Casado                2
# 4     5112956     46   Ensino superior         Casado                2
#
#   Categoria_de_renda       Ocupacao  Anos_empregado  Rendimento_anual  \
# 0          Empregado          Outro              12          427500.0
# 1          Empregado          Outro              12          427500.0
# 2          Empregado      Segurança               3          112500.0
# 3          Empregado  Contabilidade               2          270000.0
# 4          Empregado  Contabilidade               2          270000.0
#
#    Tem_carro                   Moradia
# 0          1       Apartamento alugado
# ...

# %%
#Transformando o dataframe em uma tabela no engine
empregados.to_sql('empregados', con = engine, index = False)
# Out:
# 226059

# %%
inspetor = inspect(engine)
print(inspetor.get_table_names())
# Out:
# ['clientes', 'empregados']

# %%
#lendo uma tabela SQL completa
pd.read_sql_table('empregados', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008815     46   Ensino superior         Casado                2
# 4          5112956     46   Ensino superior         Casado                2
# ...            ...    ...               ...            ...              ...
# 226054     6837905     43      Ensino médio         Casado                3
# 226055     6837906     43      Ensino médio         Casado                3
# 226056     6839936     34      Ensino médio         Casado                3
# 226057     6840222     43      Ensino médio       Solteiro                1
# 226058     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
#lendo a tabela porém com colunas específicas
pd.read_sql_table('empregados', engine, columns = ['ID_Cliente', 'Grau_escolaridade', 'Rendimento_anual'])
# Out:
#         ID_Cliente Grau_escolaridade  Rendimento_anual
# 0          5008804   Ensino superior          427500.0
# 1          5008805   Ensino superior          427500.0
# 2          5008806      Ensino médio          112500.0
# 3          5008815   Ensino superior          270000.0
# 4          5112956   Ensino superior          270000.0
# ...            ...               ...               ...
# 226054     6837905      Ensino médio          355050.0
# 226055     6837906      Ensino médio          355050.0
# 226056     6839936      Ensino médio          135000.0
# 226057     6840222      Ensino médio          103500.0
# 226058     6842885      Ensino médio          121500.0
#
# [226059 rows x 3 columns]

# %%
#Esta função é essencial para criar e executar expressões SQL literais dentro do seu código Python

from sqlalchemy import text

# %%
#Exemplo de execução

query = 'DELETE FROM clientes WHERE ID_Cliente=5008804'
with engine.connect() as conn:
    result = conn.execute(text(query))
    conn.commit()

# %%
query = 'SELECT * FROM clientes'
clientes = pd.read_sql(query, engine)

# %%
clientes
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008805     32   Ensino superior  União-estável                2
# 1          5008806     58      Ensino médio         Casado                2
# 2          5008808     52      Ensino médio       Solteiro                1
# 3          5008809     52      Ensino médio       Solteiro                1
# 4          5008810     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438457     6840104     62      Ensino médio     Divorciado                1
# 438458     6840222     43      Ensino médio       Solteiro                1
# 438459     6841878     22   Ensino superior       Solteiro                1
# 438460     6842765     59      Ensino médio         Casado                2
# 438461     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
query = 'DELETE FROM clientes WHERE ID_Cliente = 5008805'

with engine.connect() as conn:
  conn.execute(text(query))
  conn.commit()

# %%
pd.read_sql_table('clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade Estado_civil  Tamanho_familia  \
# 0          5008806     58      Ensino médio       Casado                2
# 1          5008808     52      Ensino médio     Solteiro                1
# 2          5008809     52      Ensino médio     Solteiro                1
# 3          5008810     52      Ensino médio     Solteiro                1
# 4          5008811     52      Ensino médio     Solteiro                1
# ...            ...    ...               ...          ...              ...
# 438456     6840104     62      Ensino médio   Divorciado                1
# 438457     6840222     43      Ensino médio     Solteiro                1
# 438458     6841878     22   Ensino superior     Solteiro                1
# 438459     6842765     59      Ensino médio       Casado                2
# 438460     6842885     51      Ensino médio       Casado                2
#
#          Categoria_de_renda          Ocupacao  Anos_empregado  \
# ...

# %%
query = 'UPDATE clientes SET Grau_escolaridade = "Ensino superior" where ID_Cliente = 5008808'

# %%
with engine.connect() as conn:
  conn.execute(text(query))
  conn.commit()

# %%
pd.read_sql_table('clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade Estado_civil  Tamanho_familia  \
# 0          5008806     58      Ensino médio       Casado                2
# 1          5008808     52   Ensino superior     Solteiro                1
# 2          5008809     52      Ensino médio     Solteiro                1
# 3          5008810     52      Ensino médio     Solteiro                1
# 4          5008811     52      Ensino médio     Solteiro                1
# ...            ...    ...               ...          ...              ...
# 438456     6840104     62      Ensino médio   Divorciado                1
# 438457     6840222     43      Ensino médio     Solteiro                1
# 438458     6841878     22   Ensino superior     Solteiro                1
# 438459     6842765     59      Ensino médio       Casado                2
# 438460     6842885     51      Ensino médio       Casado                2
#
#          Categoria_de_renda          Ocupacao  Anos_empregado  \
# ...

# %%
#Desafio: manipulando um banco de dados

#importando bibliotecas, classes, funções
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine, MetaData, Table, inspect, text

#criando um banco de dados do tipo sqlite, armazenar o banco na memória local
engine = create_engine('sqlite:///:memory:')

#url com a base de dados
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/clientes_banco.csv'

#criando um dataframe a partir do csv
clientes_banco = pd.read_csv(url)

# %%
#conferindo os dados importados
clientes_banco.head()
# Out:
#    ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0     5008804     32   Ensino superior  União-estável                2
# 1     5008805     32   Ensino superior  União-estável                2
# 2     5008806     58      Ensino médio         Casado                2
# 3     5008808     52      Ensino médio       Solteiro                1
# 4     5008809     52      Ensino médio       Solteiro                1
#
#     Categoria_de_renda   Ocupacao  Anos_empregado  Rendimento_anual  \
# 0            Empregado      Outro              12          427500.0
# 1            Empregado      Outro              12          427500.0
# 2            Empregado  Segurança               3          112500.0
# 3  Associado comercial     Vendas               8          270000.0
# 4  Associado comercial     Vendas               8          270000.0
#
#    Tem_carro                   Moradia
# 0          1       Apartamento alugado
# 1          1       Apartamento alugado
# ...

# %%
#criando a tabela clientes_banco
clientes_banco.to_sql('clientes_banco', engine, index = False)
# Out:
# 438463

# %%
#conferindo a tabela criada
pd.read_sql_table('clientes_banco', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008809     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840104     62      Ensino médio     Divorciado                1
# 438459     6840222     43      Ensino médio       Solteiro                1
# 438460     6841878     22   Ensino superior       Solteiro                1
# 438461     6842765     59      Ensino médio         Casado                2
# 438462     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
#criando as queries
query_1 = 'UPDATE clientes_banco SET Rendimento_anual = 300000 WHERE ID_Cliente = 6840104'
query_2 = 'DELETE FROM clientes_banco WHERE ID_Cliente = 5008809'
query_3 = 'INSERT INTO clientes_banco (ID_Cliente,Idade,Grau_escolaridade,Estado_civil,Tamanho_familia,\
          Categoria_de_renda,Ocupacao,Anos_empregado,Rendimento_anual,Tem_carro,Moradia) VALUES \
          (6850985, 33, "Doutorado", "Solteiro", 1, "Empregado", "TI", 2, 290000, 0, "Casa/apartamento próprio")'

# %%
#conferindo os dados antes de serem alterados
pd.read_sql_query('SELECT * FROM clientes_banco WHERE ID_Cliente = 6840104', engine)
# Out:
#    ID_Cliente  Idade Grau_escolaridade Estado_civil  Tamanho_familia  \
# 0     6840104     62      Ensino médio   Divorciado                1
#
#   Categoria_de_renda Ocupacao  Anos_empregado  Rendimento_anual  Tem_carro  \
# 0        Pensionista    Outro               0          135000.0          0
#
#                     Moradia
# 0  Casa/apartamento próprio

# %%
#conferindo os dados antes de serem alterados
pd.read_sql_query('SELECT * FROM clientes_banco WHERE ID_Cliente = 5008809', engine)
# Out:
#    ID_Cliente  Idade Grau_escolaridade Estado_civil  Tamanho_familia  \
# 0     5008809     52      Ensino médio     Solteiro                1
#
#     Categoria_de_renda Ocupacao  Anos_empregado  Rendimento_anual  Tem_carro  \
# 0  Associado comercial   Vendas               8          270000.0          0
#
#                     Moradia
# 0  Casa/apartamento próprio

# %%
#executando as queries
with engine.connect() as conn:
  conn.execute(text(query_1))
  conn.execute(text(query_2))
  conn.execute(text(query_3))
  conn.commit()

# %%
#conferindo os dados depois de serem alterados
pd.read_sql_query('SELECT * FROM clientes_banco WHERE ID_Cliente = 6840104', engine)
# Out:
#    ID_Cliente  Idade Grau_escolaridade Estado_civil  Tamanho_familia  \
# 0     6840104     62      Ensino médio   Divorciado                1
#
#   Categoria_de_renda Ocupacao  Anos_empregado  Rendimento_anual  Tem_carro  \
# 0        Pensionista    Outro               0          300000.0          0
#
#                     Moradia
# 0  Casa/apartamento próprio

# %%
#conferindo os dados depois de serem alterados
pd.read_sql_query('SELECT * FROM clientes_banco WHERE ID_Cliente = 5008809', engine)
# Out:
# Empty DataFrame
# Columns: [ID_Cliente, Idade, Grau_escolaridade, Estado_civil, Tamanho_familia, Categoria_de_renda, Ocupacao, Anos_empregado, Rendimento_anual, Tem_carro, Moradia]
# Index: []

# %%
#conferindo os dados depois de serem alterados
pd.read_sql_table('clientes_banco', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008810     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840222     43      Ensino médio       Solteiro                1
# 438459     6841878     22   Ensino superior       Solteiro                1
# 438460     6842765     59      Ensino médio         Casado                2
# 438461     6842885     51      Ensino médio         Casado                2
# 438462     6850985     33         Doutorado       Solteiro                1
#
# ...
